# %% [markdown]
# # Data exploring

# %% [markdown]
# We would like to to help us gain insights into how people feel about their local communities in Scotland. In particular, we are interested in the relationship between distance to outdoor space, and neighbourhood ratings.
#
# 1. Are there certain groups that have local access to green space?
# 2. Are there groups that are lacking access?
# 3. What there big differences in how far people have to walk to access their green space?
# 4. Are there any differences between rural and urban areas?
# 5. How do people in neighbourhoods with good access to green space differ from those who have no good access? Are there differences in how they rate their neighbourhoods? Are there differences in how they rate their communities?
# 6. Is there any way to predict which households would have higher ratings?

# %%
import pandas as pd 
import numpy as np 
import pandas_profiling
from janitor import clean_names

# %%
green_blue = pd.read_csv('raw_data/dis_green_blue.csv').clean_names()
n_rate = pd.read_csv('raw_data/neighbourhood_rate.csv').clean_names()
belong = pd.read_csv('raw_data/community_belonging.csv').clean_names()

# %%
green_blue.measurement.unique()
# Out:
# array(['95% Upper Confidence Limit, Percent',
#        '95% Lower Confidence Limit, Percent', 'Percent'], dtype=object)

# %%
green_blue.head()
# Out:
#   featurecode       featurename   featuretype  datecode  \
# 0   S12000027  Shetland Islands  Council Area      2015
# 1   S12000027  Shetland Islands  Council Area      2015
# 2   S12000014           Falkirk  Council Area      2017
# 3   S12000027  Shetland Islands  Council Area      2016
# 4   S12000027  Shetland Islands  Council Area      2015
#
#                            measurement              units  value  \
# 0  95% Upper Confidence Limit, Percent  Percent Of Adults   14.1
# 1  95% Upper Confidence Limit, Percent  Percent Of Adults   14.4
# 2  95% Upper Confidence Limit, Percent  Percent Of Adults   40.1
# 3  95% Lower Confidence Limit, Percent  Percent Of Adults    3.1
# 4  95% Upper Confidence Limit, Percent  Percent Of Adults   14.3
#
#   distance_to_nearest_green_or_blue_space                age gender  \
# 0               Within a 6-10 minute walk                All   Male
# 1               Within a 6-10 minute walk                All    All
# 2               Within a 6-10 minute walk  65 years and over    All
# 3               Within a 6-10 minute walk                All    All
# 4               Within a 6-10 minute walk                All    All
#
#   urban_rural_classification simd_quintiles       type_of_tenure  \
# 0                        All            All                  All
# 1                        All            All                  All
# 2                        All            All                  All
# 3                        All            All                  All
# 4                        All            All  Owned Mortgage/Loan
#
#   household_type ethnicity
# 0            All       All
# 1     Pensioners       All
# 2            All       All
# 3         Adults       All
# 4            All       All

# %%
#pandas_profiling.ProfileReport(green_blue)

# %%
green_blue.columns
# Out:
# Index(['featurecode', 'featurename', 'featuretype', 'datecode', 'measurement',
#        'units', 'value', 'distance_to_nearest_green_or_blue_space', 'age',
#        'gender', 'urban_rural_classification', 'simd_quintiles',
#        'type_of_tenure', 'household_type', 'ethnicity'],
#       dtype='object')

# %%
n_rate.head()
# Out:
#   featurecode        featurename   featuretype  datecode  \
# 0   S12000029  South Lanarkshire  Council Area      2017
# 1   S12000029  South Lanarkshire  Council Area      2017
# 2   S12000033      Aberdeen City  Council Area      2019
# 3   S12000033      Aberdeen City  Council Area      2019
# 4   S12000036  City of Edinburgh  Council Area      2016
#
#                            measurement              units  value  \
# 0  95% Lower Confidence Limit, Percent  Percent Of Adults   24.8
# 1  95% Upper Confidence Limit, Percent  Percent Of Adults   49.1
# 2  95% Upper Confidence Limit, Percent  Percent Of Adults   57.0
# 3                              Percent  Percent Of Adults   45.0
# 4  95% Upper Confidence Limit, Percent  Percent Of Adults   56.2
#
#   neighbourhood_rating gender urban_rural_classification simd_quintiles  \
# 0          Fairly good    All                        All            All
# 1          Fairly good    All                        All            All
# 2          Fairly good    All                        All            All
# 3          Fairly good    All                        All            All
# 4          Fairly good    All                        All            All
#
#   type_of_tenure household_type ethnicity  \
# 0            All            All       All
# 1            All            All       All
# 2            All            All       All
# 3            All            All       All
# 4            All            All       All
#
#   walking_distance_to_nearest_greenspace
# 0                   More than 10 minutes
# 1                   More than 10 minutes
# 2                   More than 10 minutes
# 3                   More than 10 minutes
# 4                   More than 10 minutes

# %%
#pandas_profiling.ProfileReport(n_rate)

# %%
belong.head()
# Out:
#   featurecode        featurename   featuretype  datecode  \
# 0   S12000011  East Renfrewshire  Council Area      2017
# 1   S12000011  East Renfrewshire  Council Area      2017
# 2   S92000003           Scotland       Country      2016
# 3   S12000011  East Renfrewshire  Council Area      2017
# 4   S12000049       Glasgow City  Council Area      2017
#
#                            measurement              units  value  \
# 0  95% Upper Confidence Limit, Percent  Percent Of Adults    7.8
# 1  95% Lower Confidence Limit, Percent  Percent Of Adults    0.0
# 2                              Percent  Percent Of Adults   40.0
# 3                              Percent  Percent Of Adults    3.0
# 4  95% Lower Confidence Limit, Percent  Percent Of Adults   34.2
#
#    community_belonging gender urban_rural_classification simd_quintiles  \
# 0  Not at all strongly    All                        All            All
# 1  Not at all strongly    All                        All            All
# 2      Fairly strongly    All                        All            All
# 3  Not at all strongly    All                        All            All
# 4      Fairly strongly    All                        All            All
#
#   type_of_tenure household_type ethnicity  \
# 0            All            All       All
# 1            All            All       All
# 2            All            All       All
# 3            All            All       All
# 4            All            All       All
#
#   walking_distance_to_nearest_greenspace
# 0                   More than 10 minutes
# 1                   More than 10 minutes
# 2                   More than 10 minutes
# 3                   More than 10 minutes
# 4                   More than 10 minutes

# %%
#pandas_profiling.ProfileReport(belong)

# %%
# they are so similar

# %% [markdown]
# # Cleaning

# %% [markdown]
# ### green_blue cleaning

# %%
green_blue.isna().sum()
# Out:
# featurecode                                0
# featurename                                0
# featuretype                                0
# datecode                                   0
# measurement                                0
# units                                      0
# value                                      0
# distance_to_nearest_green_or_blue_space    0
# age                                        0
# gender                                     0
# urban_rural_classification                 0
# simd_quintiles                             0
# type_of_tenure                             0
# household_type                             0
# ethnicity                                  0
# dtype: int64

# %%
green_blue.head()
# Out:
#   featurecode       featurename   featuretype  datecode  \
# 0   S12000027  Shetland Islands  Council Area      2015
# 1   S12000027  Shetland Islands  Council Area      2015
# 2   S12000014           Falkirk  Council Area      2017
# 3   S12000027  Shetland Islands  Council Area      2016
# 4   S12000027  Shetland Islands  Council Area      2015
#
#                            measurement              units  value  \
# 0  95% Upper Confidence Limit, Percent  Percent Of Adults   14.1
# 1  95% Upper Confidence Limit, Percent  Percent Of Adults   14.4
# 2  95% Upper Confidence Limit, Percent  Percent Of Adults   40.1
# 3  95% Lower Confidence Limit, Percent  Percent Of Adults    3.1
# 4  95% Upper Confidence Limit, Percent  Percent Of Adults   14.3
#
#   distance_to_nearest_green_or_blue_space                age gender  \
# 0               Within a 6-10 minute walk                All   Male
# 1               Within a 6-10 minute walk                All    All
# 2               Within a 6-10 minute walk  65 years and over    All
# 3               Within a 6-10 minute walk                All    All
# 4               Within a 6-10 minute walk                All    All
#
#   urban_rural_classification simd_quintiles       type_of_tenure  \
# 0                        All            All                  All
# 1                        All            All                  All
# 2                        All            All                  All
# 3                        All            All                  All
# 4                        All            All  Owned Mortgage/Loan
#
#   household_type ethnicity
# 0            All       All
# 1     Pensioners       All
# 2            All       All
# 3         Adults       All
# 4            All       All

# %%
green_blue.drop(['featurecode','featurename','featuretype','measurement','units'], axis = 1, inplace = True)

# %%
green_blue
# Out:
#        datecode  value distance_to_nearest_green_or_blue_space  \
# 0          2015   14.1               Within a 6-10 minute walk
# 1          2015   14.4               Within a 6-10 minute walk
# 2          2017   40.1               Within a 6-10 minute walk
# 3          2016    3.1               Within a 6-10 minute walk
# 4          2015   14.3               Within a 6-10 minute walk
# ...         ...    ...                                     ...
# 38446      2018    2.0                              Don't Know
# 38447      2017   27.0               Within a 6-10 minute walk
# 38448      2017   33.0               Within a 6-10 minute walk
# 38449      2017   50.0                 A 5 minute walk or less
# 38450      2014   18.0               An 11 minute walk or more
#
#                      age gender urban_rural_classification simd_quintiles  \
# 0                    All   Male                        All            All
# 1                    All    All                        All            All
# 2      65 years and over    All                        All            All
# 3                    All    All                        All            All
# 4                    All    All                        All            All
# ...                  ...    ...                        ...            ...
# 38446                All    All                        All            All
# 38447                All    All                        All            All
# 38448                All    All                        All            All
# 38449                All    All                        All            All
# 38450                All    All                        All            All
#
#             type_of_tenure household_type ethnicity
# 0                      All            All       All
# 1                      All     Pensioners       All
# 2                      All            All       All
# 3                      All         Adults       All
# 4      Owned Mortgage/Loan            All       All
# ...                    ...            ...       ...
# 38446                  All            All     Other
# 38447                  All            All     Other
# 38448                  All            All     Other
# 38449                  All            All     Other
# 38450                  All            All     Other
#
# [38451 rows x 10 columns]

# %%
(green_blue['distance_to_nearest_green_or_blue_space'].replace({'Within a 6-10 minute walk': 'Less than 10 minutes',
                                                                'A 5 minute walk or less': 'Less than 10 minutes',
                                                                'An 11 minute walk or more': 'More than 10 minutes'}, inplace = True)
)

# %%
green_blue[green_blue.distance_to_nearest_green_or_blue_space == "Don't Know"]
#7347 rows
# Out:
#        datecode  value distance_to_nearest_green_or_blue_space  age  gender  \
# 18511      2016    0.0                              Don't Know  All     All
# 18512      2013    0.0                              Don't Know  All     All
# 18513      2016    0.0                              Don't Know  All  Female
# 18514      2013   13.4                              Don't Know  All     All
# 18515      2013    1.0                              Don't Know  All  Female
# ...         ...    ...                                     ...  ...     ...
# 38426      2019    2.1                              Don't Know  All     All
# 38441      2016    0.0                              Don't Know  All     All
# 38443      2018    3.6                              Don't Know  All     All
# 38445      2013    0.0                              Don't Know  All     All
# 38446      2018    2.0                              Don't Know  All     All
#
#       urban_rural_classification simd_quintiles type_of_tenure household_type  \
# 18511                        All            All            All  With Children
# 18512                      Urban            All            All            All
# 18513                        All            All            All            All
# 18514                        All            All            All     Pensioners
# 18515                        All            All            All            All
# ...                          ...            ...            ...            ...
# 38426                        All            All            All            All
# 38441                        All            All            All            All
# 38443                        All            All            All            All
# 38445                        All            All            All            All
# 38446                        All            All            All            All
#
#       ethnicity
# 18511       All
# 18512       All
# 18513       All
# 18514       All
# 18515       All
# ...         ...
# 38426     Other
# 38441     Other
# 38443     Other
# 38445     Other
# 38446     Other
#
# [7347 rows x 10 columns]

# %%
green_blue.shape
#38451 rows
# Out:
# (38451, 10)

# %% [markdown]
# ```
# it's about 19% of the data that has the distance to green sapce as 'Don't know', it's a lot to drop
# but they are not very helpful otherwise.
# ```

# %%
green_blue = green_blue[green_blue.distance_to_nearest_green_or_blue_space != "Don't Know"]
green_blue
# Out:
#        datecode  value distance_to_nearest_green_or_blue_space  \
# 0          2015   14.1                    Less than 10 minutes
# 1          2015   14.4                    Less than 10 minutes
# 2          2017   40.1                    Less than 10 minutes
# 3          2016    3.1                    Less than 10 minutes
# 4          2015   14.3                    Less than 10 minutes
# ...         ...    ...                                     ...
# 38444      2016   23.0                    Less than 10 minutes
# 38447      2017   27.0                    Less than 10 minutes
# 38448      2017   33.0                    Less than 10 minutes
# 38449      2017   50.0                    Less than 10 minutes
# 38450      2014   18.0                    More than 10 minutes
#
#                      age gender urban_rural_classification simd_quintiles  \
# 0                    All   Male                        All            All
# 1                    All    All                        All            All
# 2      65 years and over    All                        All            All
# 3                    All    All                        All            All
# 4                    All    All                        All            All
# ...                  ...    ...                        ...            ...
# 38444                All    All                        All            All
# 38447                All    All                        All            All
# 38448                All    All                        All            All
# 38449                All    All                        All            All
# 38450                All    All                        All            All
#
#             type_of_tenure household_type ethnicity
# 0                      All            All       All
# 1                      All     Pensioners       All
# 2                      All            All       All
# 3                      All         Adults       All
# 4      Owned Mortgage/Loan            All       All
# ...                    ...            ...       ...
# 38444                  All            All     Other
# 38447                  All            All     Other
# 38448                  All            All     Other
# 38449                  All            All     Other
# 38450                  All            All     Other
#
# [31104 rows x 10 columns]

# %%
green_blue[green_blue.featurecode == 'S12000027']
# Out:
#       featurecode   featuretype distance_to_nearest_green_or_blue_space  age  \
# 0       S12000027  Council Area                    Less than 10 minutes  All
# 1       S12000027  Council Area                    Less than 10 minutes  All
# 3       S12000027  Council Area                    Less than 10 minutes  All
# 4       S12000027  Council Area                    Less than 10 minutes  All
# 6       S12000027  Council Area                    Less than 10 minutes  All
# ...           ...           ...                                     ...  ...
# 37960   S12000027  Council Area                    Less than 10 minutes  All
# 38068   S12000027  Council Area                    Less than 10 minutes  All
# 38108   S12000027  Council Area                    Less than 10 minutes  All
# 38116   S12000027  Council Area                    Less than 10 minutes  All
# 38117   S12000027  Council Area                    Less than 10 minutes  All
#
#       gender urban_rural_classification      simd_quintiles  \
# 0       Male                        All                 All
# 1        All                        All                 All
# 3        All                        All                 All
# 4        All                        All                 All
# 6        All                        All  80% least deprived
# ...      ...                        ...                 ...
# 37960    All                        All                 All
# 38068    All                        All                 All
# 38108    All                        All                 All
# 38116    All                        All                 All
# 38117    All                        All                 All
#
#             type_of_tenure household_type ethnicity
# 0                      All            All       All
# 1                      All     Pensioners       All
# 3                      All         Adults       All
# 4      Owned Mortgage/Loan            All       All
# 6                      All            All       All
# ...                    ...            ...       ...
# 37960                  All            All     White
# 38068                  All            All     White
# 38108                  All            All     White
# 38116                  All            All     White
# 38117                  All            All     White
#
# [945 rows x 10 columns]

# %%
# ummmm be careful with the 'ALl' 
# if i am thinking of building a model i shouldn't have those all????

# %% [markdown]
# ### n_rate cleaning

# %%
n_rate.head()
# Out:
#   featurecode        featurename   featuretype  datecode  \
# 0   S12000029  South Lanarkshire  Council Area      2017
# 1   S12000029  South Lanarkshire  Council Area      2017
# 2   S12000033      Aberdeen City  Council Area      2019
# 3   S12000033      Aberdeen City  Council Area      2019
# 4   S12000036  City of Edinburgh  Council Area      2016
#
#                            measurement              units  value  \
# 0  95% Lower Confidence Limit, Percent  Percent Of Adults   24.8
# 1  95% Upper Confidence Limit, Percent  Percent Of Adults   49.1
# 2  95% Upper Confidence Limit, Percent  Percent Of Adults   57.0
# 3                              Percent  Percent Of Adults   45.0
# 4  95% Upper Confidence Limit, Percent  Percent Of Adults   56.2
#
#   neighbourhood_rating gender urban_rural_classification simd_quintiles  \
# 0          Fairly good    All                        All            All
# 1          Fairly good    All                        All            All
# 2          Fairly good    All                        All            All
# 3          Fairly good    All                        All            All
# 4          Fairly good    All                        All            All
#
#   type_of_tenure household_type ethnicity  \
# 0            All            All       All
# 1            All            All       All
# 2            All            All       All
# 3            All            All       All
# 4            All            All       All
#
#   walking_distance_to_nearest_greenspace
# 0                   More than 10 minutes
# 1                   More than 10 minutes
# 2                   More than 10 minutes
# 3                   More than 10 minutes
# 4                   More than 10 minutes

# %%
n_rate.shape
# Out:
# (38055, 15)

# %%
n_rate.drop(['featurecode','featurename','featuretype','measurement','units'], axis = 1,inplace = True)

# %%
n_rate
# Out:
#        datecode  value neighbourhood_rating gender urban_rural_classification  \
# 0          2017   24.8          Fairly good    All                        All
# 1          2017   49.1          Fairly good    All                        All
# 2          2019   57.0          Fairly good    All                        All
# 3          2019   45.0          Fairly good    All                        All
# 4          2016   56.2          Fairly good    All                        All
# ...         ...    ...                  ...    ...                        ...
# 38050      2013   42.0          Fairly good    All                        All
# 38051      2017   53.3          Fairly good    All                      Rural
# 38052      2017   20.2          Fairly good    All                      Rural
# 38053      2016   31.0          Fairly good    All                        All
# 38054      2013   31.8          Fairly good    All                        All
#
#       simd_quintiles type_of_tenure household_type ethnicity  \
# 0                All            All            All       All
# 1                All            All            All       All
# 2                All            All            All       All
# 3                All            All            All       All
# 4                All            All            All       All
# ...              ...            ...            ...       ...
# 38050            All            All            All     White
# 38051            All            All            All       All
# 38052            All            All            All       All
# 38053            All            All  With Children       All
# 38054            All            All     Pensioners       All
#
#       walking_distance_to_nearest_greenspace
# 0                       More than 10 minutes
# 1                       More than 10 minutes
# 2                       More than 10 minutes
# 3                       More than 10 minutes
# 4                       More than 10 minutes
# ...                                      ...
# 38050                                    All
# 38051                                    All
# 38052                                    All
# 38053                                    All
# 38054                                    All
#
# [38055 rows x 10 columns]

# %%
belong.shape
# Out:
# (43611, 15)

# %%
belong.drop(['featurecode','featurename','featuretype','measurement','units'], axis = 1, inplace = True)
belong
# Out:
#        datecode  value  community_belonging  gender  \
# 0          2017    7.8  Not at all strongly     All
# 1          2017    0.0  Not at all strongly     All
# 2          2016   40.0      Fairly strongly     All
# 3          2017    3.0  Not at all strongly     All
# 4          2017   34.2      Fairly strongly     All
# ...         ...    ...                  ...     ...
# 43606      2019    3.3    Not very strongly     All
# 43607      2014    9.6    Not very strongly     All
# 43608      2017   16.0    Not very strongly     All
# 43609      2018   16.0    Not very strongly  Female
# 43610      2018   24.5    Not very strongly  Female
#
#       urban_rural_classification simd_quintiles type_of_tenure household_type  \
# 0                            All            All            All            All
# 1                            All            All            All            All
# 2                            All            All            All            All
# 3                            All            All            All            All
# 4                            All            All            All            All
# ...                          ...            ...            ...            ...
# 43606                        All            All            All         Adults
# 43607                        All            All            All            All
# 43608                        All            All            All            All
# 43609                        All            All            All            All
# 43610                        All            All            All            All
#
#       ethnicity walking_distance_to_nearest_greenspace
# 0           All                   More than 10 minutes
# 1           All                   More than 10 minutes
# 2           All                   More than 10 minutes
# 3           All                   More than 10 minutes
# 4           All                   More than 10 minutes
# ...         ...                                    ...
# 43606       All                                    All
# 43607     White                                    All
# 43608       All                                    All
# 43609       All                                    All
# 43610       All                                    All
#
# [43611 rows x 10 columns]

# %%
# how do i handle the all and how do i join them together.

# %%
# testing

# %%
df_a = pd.DataFrame({'a':[1,2,3],'b' : [3,3,3]})
df_b = pd.DataFrame({'a':[3,2,1], 'c': [1,1,1]})

# %%
df_a
# Out:
#    a  b
# 0  1  3
# 1  2  3
# 2  3  3

# %%
df_b
# Out:
#    a  c
# 0  3  1
# 1  2  1
# 2  1  1

# %%
pd.concat([df_a,df_b], axis=1)
# Out:
#    a  b  a  c
# 0  1  3  3  1
# 1  2  3  2  1
# 2  3  3  1  1

# %%
df_a.merge(df_b, left_index=True, right_index=True)
# Out:
#    a_x  b  a_y  c
# 0    1  3    3  1
# 1    2  3    2  1
# 2    3  3    1  1

# %%
pd.concat([df_a, df_b], ignore_index=True,axis=0)
# Out:
#    a    b    c
# 0  1  3.0  NaN
# 1  2  3.0  NaN
# 2  3  3.0  NaN
# 3  3  NaN  1.0
# 4  2  NaN  1.0
# 5  1  NaN  1.0

# %%
# end of testing

# %%
green_blue.columns
# Out:
# Index(['featurecode', 'featuretype', 'distance_to_nearest_green_or_blue_space',
#        'age', 'gender', 'urban_rural_classification', 'simd_quintiles',
#        'type_of_tenure', 'household_type', 'ethnicity'],
#       dtype='object')

# %%
n_rate.columns
# Out:
# Index(['featurecode', 'featuretype', 'neighbourhood_rating', 'gender',
#        'urban_rural_classification', 'simd_quintiles', 'type_of_tenure',
#        'household_type', 'ethnicity',
#        'walking_distance_to_nearest_greenspace'],
#       dtype='object')

# %%
belong.columns
# Out:
# Index(['featurecode', 'featuretype', 'community_belonging', 'gender',
#        'urban_rural_classification', 'simd_quintiles', 'type_of_tenure',
#        'household_type', 'ethnicity',
#        'walking_distance_to_nearest_greenspace'],
#       dtype='object')

# %%
green_blue.rename(columns={'distance_to_nearest_green_or_blue_space': 'walking_distance_to_nearest_greenspace'}, inplace = True)
green_blue
# Out:
# /var/folders/h4/vy1nwyvd5kz_n6950nl29pj80000gn/T/ipykernel_76673/1033909748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   green_blue.rename(columns={'distance_to_nearest_green_or_blue_space': 'walking_distance_to_nearest_greenspace'}, inplace = True)
#        datecode  value walking_distance_to_nearest_greenspace  \
# 0          2015   14.1                   Less than 10 minutes
# 1          2015   14.4                   Less than 10 minutes
# 2          2017   40.1                   Less than 10 minutes
# 3          2016    3.1                   Less than 10 minutes
# 4          2015   14.3                   Less than 10 minutes
# ...         ...    ...                                    ...
# 38444      2016   23.0                   Less than 10 minutes
# 38447      2017   27.0                   Less than 10 minutes
# 38448      2017   33.0                   Less than 10 minutes
# 38449      2017   50.0                   Less than 10 minutes
# 38450      2014   18.0                   More than 10 minutes
#
#                      age gender urban_rural_classification simd_quintiles  \
# 0                    All   Male                        All            All
# 1                    All    All                        All            All
# 2      65 years and over    All                        All            All
# 3                    All    All                        All            All
# 4                    All    All                        All            All
# ...                  ...    ...                        ...            ...
# 38444                All    All                        All            All
# 38447                All    All                        All            All
# 38448                All    All                        All            All
# 38449                All    All                        All            All
# 38450                All    All                        All            All
#
#             type_of_tenure household_type ethnicity
# 0                      All            All       All
# 1                      All     Pensioners       All
# 2                      All            All       All
# 3                      All         Adults       All
# 4      Owned Mortgage/Loan            All       All
# ...                    ...            ...       ...
# 38444                  All            All     Other
# 38447                  All            All     Other
# 38448                  All            All     Other
# 38449                  All            All     Other
# 38450                  All            All     Other
#
# [31104 rows x 10 columns]

# %%
df = pd.concat([green_blue, n_rate, belong], ignore_index=True,axis=0)

df
# Out:
#         datecode  value walking_distance_to_nearest_greenspace  \
# 0           2015   14.1                   Less than 10 minutes
# 1           2015   14.4                   Less than 10 minutes
# 2           2017   40.1                   Less than 10 minutes
# 3           2016    3.1                   Less than 10 minutes
# 4           2015   14.3                   Less than 10 minutes
# ...          ...    ...                                    ...
# 112765      2019    3.3                                    All
# 112766      2014    9.6                                    All
# 112767      2017   16.0                                    All
# 112768      2018   16.0                                    All
# 112769      2018   24.5                                    All
#
#                       age  gender urban_rural_classification simd_quintiles  \
# 0                     All    Male                        All            All
# 1                     All     All                        All            All
# 2       65 years and over     All                        All            All
# 3                     All     All                        All            All
# 4                     All     All                        All            All
# ...                   ...     ...                        ...            ...
# 112765                NaN     All                        All            All
# 112766                NaN     All                        All            All
# 112767                NaN     All                        All            All
# 112768                NaN  Female                        All            All
# 112769                NaN  Female                        All            All
#
#              type_of_tenure household_type ethnicity neighbourhood_rating  \
# 0                       All            All       All                  NaN
# 1                       All     Pensioners       All                  NaN
# 2                       All            All       All                  NaN
# 3                       All         Adults       All                  NaN
# 4       Owned Mortgage/Loan            All       All                  NaN
# ...                     ...            ...       ...                  ...
# 112765                  All         Adults       All                  NaN
# 112766                  All            All     White                  NaN
# 112767                  All            All       All                  NaN
# 112768                  All            All       All                  NaN
# 112769                  All            All       All                  NaN
#
#        community_belonging
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 112765   Not very strongly
# 112766   Not very strongly
# 112767   Not very strongly
# 112768   Not very strongly
# 112769   Not very strongly
#
# [112770 rows x 12 columns]

# %%
df.to_csv('clean_data/green.csv',index=False)
